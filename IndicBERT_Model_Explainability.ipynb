# %% [markdown]
# # Importing libararies

# %%
import sys
import subprocess
import os
import numpy as np
import pandas as pd
import re
import seaborn as sns
import torch
import matplotlib.pyplot as plt
from collections import Counter
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline, AlbertTokenizer
import shap
from lime.lime_text import LimeTextExplainer
from scipy.stats import pearsonr
from scipy.spatial.distance import jensenshannon
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# %% [markdown]
# # Setting paths

# %%
# Setting paths for model, data, and results
MODEL_DIR = "./indicbert_hate_model_v2_final"
DATA_PATH = "./hindi_hatespeech_cleaned.csv"   
RESULTS_DIR = "./indicbert_explainability"

os.makedirs(RESULTS_DIR, exist_ok=True)

model_path = MODEL_DIR
print(f"\nModel directory: {MODEL_DIR}")
print(f"Results directory: {RESULTS_DIR}")
print(f"Data path: {DATA_PATH}")
# Out:
# Model directory: ./indicbert_hate_model_v2_final
# Results directory: ./indicbert_explainability
# Data path: ./hindi_hatespeech_cleaned.csv

# %% [markdown]
# # Loading model and tokenizer

# %%
# Setting device
device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Loading model from: {MODEL_DIR}")

# Loading tokenizer
tokenizer_hf = AlbertTokenizer.from_pretrained("ai4bharat/indic-bert")
# Loading model
model = AutoModelForSequenceClassification.from_pretrained(MODEL_DIR)
model.to(device)
model.eval()

print("Model and tokenizer loaded successfully.")
# Out:
# Loading model from: ./indicbert_hate_model_v2_final
# Model and tokenizer loaded successfully.

# %%
# Defining a Hindi-friendly word-level tokenizer for SHAP & LIME
# This is necessary to ensure that SHAP and LIME assign imprtance to words, not alphabet
def expl_tokenizer(text: str):
    """
    Tokenizer for explainability:
    - Splits on whitespace -> word-level tokens for Hindi + code-mixed text.
    - Keeps punctuation as part of the word
    """
    if not isinstance(text, str):
        text = str(text)
    return text.split()

# %% [markdown]
# # Loading the cleaned dataset

# %%
# Loading the dataset using the specified data path
df = pd.read_csv(DATA_PATH)

print("Dataset loaded.")
print(df.head())
print(df.columns)
# Out:
# Dataset loaded.
#                                                 text  \
# 0  वक्त, इन्सान और इंग्लैंड का मौसम आपको कभी भी ध...
# 1  #कांग्रेस के इस #कमीने की #करतूत को देखिए देश ...
# 2  पाकिस्तान को फेकना था फेका गया। जो हार कर भी द...
# 3  जो शब्द तूम आज किसी और औरत के लिए यूज कर रहे व...
# 4  नेता जी हम समाजवादी सिपाही हमेशा आपके साथ है आ...
#
#                                         cleaned_text  labels
# 0  वक्त, इन्सान और इंग्लैंड का मौसम आपको कभी भी ध...       0
# 1  कांग्रेस के इस कमीने की करतूत को देखिए देश की ...       0
# 2  पाकिस्तान को फेकना था फेका गया। जो हार कर भी द...       0
# 3  जो शब्द तूम आज किसी और औरत के लिए यूज कर रहे व...       0
# 4  नेता जी हम समाजवादी सिपाही हमेशा आपके साथ है आ...       0
# Index(['text', 'cleaned_text', 'labels'], dtype='object')

# %%
# Using cleaned text for SHAP/LIME
TEXT_COL = "cleaned_text"  
LABEL_COL = "labels"

texts = df[TEXT_COL].tolist()
labels = df[LABEL_COL].tolist()

print(f"Total samples: {len(texts)}")
# Out:
# Total samples: 14127

# %% [markdown]
# # Selecting samples for SHAP/LIME

# %%
# Defining a function to select a subset of the cleaned dataset for SHAP/LIME anallysis
def get_explainability_subset(df, n_samples, random_seed=42):
    """
    Select a balanced subset for SHAP/LIME, similar to the HEARTS framework.

    Steps:
    - Extract equal hate + non-hate samples
    - Focus on moderate-length texts (20–200 chars)
    - Random sampling with reproducibility
    """

    df = df.copy()
    df["len"] = df["cleaned_text"].astype(str).apply(len)

    # Filtering to medium-length texts (avoids very short/noise)
    df_mid = df[(df["len"] > 20) & (df["len"] < 200)]

    hate = df_mid[df_mid["labels"] == 1]
    non_hate = df_mid[df_mid["labels"] == 0]

    # Calculating how many per class
    per_class = n_samples // 2

    hate_sample = hate.sample(n=min(per_class, len(hate)),
                              random_state=random_seed)
    non_hate_sample = non_hate.sample(n=min(per_class, len(non_hate)),
                                      random_state=random_seed)

    subset = pd.concat([hate_sample, non_hate_sample]).sample(
        frac=1, random_state=random_seed
    )
    
    subset = subset[["cleaned_text", "labels"]]
    
    print(f"Selected subset size: {len(subset)}")
    print("Hate:", sum(subset['labels']==1), 
          "Non-hate:", sum(subset['labels']==0))

    return subset.reset_index(drop=True)

# %%
# Adding predicted labels to the explainability subset 
def add_model_predictions(df, model, tokenizer):
    """
    Adds model predictions to the sampled dataframe.
    Creates: predicted_label column.
    """
    all_preds = []

    for text in df["cleaned_text"]:      
        enc = tokenizer(
            text,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=128
        )

        if torch.cuda.is_available():
            enc = {k: v.to("cuda") for k, v in enc.items()}
            model.to("cuda")
        else:
            model.to("cpu")

        with torch.no_grad():
            logits = model(**enc).logits
            pred = torch.argmax(logits, dim=-1).cpu().item()

        all_preds.append(pred)

    df["predicted_label"] = all_preds
    df["actual_label"] = df["labels"]  # rename for consistency
    df["dataset_name"] = "HASOC"       # or any name you prefer
    df["categorisation"] = df["labels"].map({0: "non-hate", 1: "hate"})

    return df

# %% [markdown]
# # SHAP Analysis

# %%
# Defining helper function 
def predict_proba(text_list):
    """
    Wrapper that takes a list of texts and returns an (N, 2) numpy array
    with probabilities for [non-hate, hate].
    """
    if isinstance(text_list, str):
        text_list = [text_list]

    enc = tokenizer_hf(
        text_list,
        padding=True,
        truncation=True,
        max_length=128,
        return_tensors="pt",
    )

    enc = {k: v.to(device) for k, v in enc.items()}
    model.to(device)
    model.eval()

    with torch.no_grad():
        outputs = model(**enc)
        probs = torch.softmax(outputs.logits, dim=-1).cpu().numpy()

    return probs

# %%
# Using the model and tokenizer loaded before
pipe = pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer_hf,
    return_all_scores=True,
    device=0 if torch.cuda.is_available() else -1,
)
# Out:
# Device set to use cuda:0

# %%
# Defining a function for SHAP analysis
import re
import shap

def shap_analysis(sampled_data: pd.DataFrame, text_col: str = "cleaned_text"):
    """
    Computes token-level SHAP values for each sentence in sampled_data
    using the fine-tuned IndicBERT hate-speech model.
    """

    # 1) SHAP text masker – use REGEX, not a Python function here
    # \S+ = sequences of non-whitespace chars; works fine for Hindi + code-mixed text
    masker = shap.maskers.Text(tokenizer=r"\S+")

    # 2) SHAP explainer on top of your existing HF pipeline
    explainer = shap.Explainer(pipe, masker)

    results = []
    class_names = ["LABEL_0", "LABEL_1"]  # 0=non-hate, 1=hate

    for idx, row in sampled_data.iterrows():
        text_input = [row[text_col]]

        # Run SHAP
        shap_values = explainer(text_input)  # shape: (1, tokens, classes)

        # Use stored predicted_label if present, else recompute
        if "predicted_label" in row:
            label_index = int(row["predicted_label"])
        else:
            probs = predict_proba([row[text_col]])
            label_index = int(np.argmax(probs, axis=-1)[0])

        true_label = int(row["labels"]) if "labels" in row else None

        print(
            f"Row {idx} | True: {true_label} | Pred: {label_index} "
            f"| Text: {row[text_col][:60]}..."
        )

        # Take SHAP values for that class
        specific_shap_values = shap_values.values[0, :, label_index]

        # Use the *same regex* as the masker to extract tokens
        tokens = re.findall(r"\S+", row[text_col])

        for token, value in zip(tokens, specific_shap_values):
            results.append(
                {
                    "sentence_id": idx,
                    "token": token,
                    "value_shap": float(value),
                    "sentence": row[text_col],
                    "true_label": true_label,
                    "predicted_label": label_index,
                }
            )

    return pd.DataFrame(results)

# %% [markdown]
# # LIME Analysis

# %%
# Defining a LIME analysis function 
def lime_analysis_indicbert(
    sampled_df: pd.DataFrame,
    text_col="cleaned_text",
    true_col="true_label",
    pred_col="predicted_label",
    save_path=None
):
    results = []

    # Infer num classes
    example = sampled_df[text_col].iloc[0]
    num_classes = predict_proba([example]).shape[1]
    class_names = [f"LABEL_{i}" for i in range(num_classes)]

    explainer = LimeTextExplainer(
        class_names=class_names,
        split_expression=expl_tokenizer  # Using Hindi-friendly tokenizer
    )

    for idx, row in sampled_df.iterrows():
        sentence = row[text_col]
        tokens = expl_tokenizer(sentence)

        if len(tokens) == 0:
            print(f"⚠️ Row {idx} skipped (no tokens)")
            continue

        exp = explainer.explain_instance(
            sentence,
            predict_proba,
            num_features=len(tokens),
            num_samples=1000
        )

        target_label = int(row[pred_col])
        if target_label not in exp.local_exp:
            target_label = max(exp.local_exp.keys())

        token_value_dict = dict(exp.as_list(label=target_label))

        print(f"Row {idx} | True: {row[true_col]} | Pred: {row[pred_col]} | Text: {sentence[:60]}...")

        for tok in tokens:
            results.append({
                "sentence_id": idx,
                "token": tok,
                "value_lime": float(token_value_dict.get(tok, 0.0)),
                "sentence": sentence,
                "true_label": int(row[true_col]),
                "predicted_label": int(row[pred_col])
            })

    lime_df = pd.DataFrame(results)
    if save_path:
        lime_df.to_csv(save_path, index=False)
        print(f"✅ Saved LIME results to: {save_path}")

    return lime_df

# %% [markdown]
# # Comparing SHAP/LIME

# %%
# Defining a function to merge SHAP/LIME
def merge_shap_lime(results_dir: str,
                    shap_filename: str = "shap_results_indicbert_v2.csv",
                    lime_filename: str = "lime_results_indicbert_v2.csv") -> pd.DataFrame:
    """
    Load SHAP and LIME token-level results and merge them on (sentence_id, token).

    Parameters
    ----------
    results_dir : str
        Directory where the SHAP / LIME CSVs are stored.
    shap_filename : str
        File name of SHAP CSV.
    lime_filename : str
        File name of LIME CSV.

    Returns
    -------
    merged_df : pd.DataFrame
        DataFrame with columns:
        ['sentence_id', 'token', 'value_shap', 'value_lime', ...meta columns from SHAP...]
    """
    shap_path = os.path.join(results_dir, shap_filename)
    lime_path = os.path.join(results_dir, lime_filename)

    shap_df = pd.read_csv(shap_path)
    lime_df = pd.read_csv(lime_path)

    print("SHAP shape:", shap_df.shape)
    print("LIME shape:", lime_df.shape)

    # Inner-join on sentence_id + token; keep meta columns from SHAP side
    merged_df = pd.merge(
        shap_df,
        lime_df[["sentence_id", "token", "value_lime"]],
        on=["sentence_id", "token"],
        how="inner"
    )

    print("\nMerged shape:", merged_df.shape)
    return merged_df

# %% [markdown]
# # Confidence Scores

# %%
# Defining a function to compute confidence scores for SHAP and LIME analysis
def compute_shap_lime_similarity(
    merged_df: pd.DataFrame,
    results_dir: str,
    out_name: str = "similarity_confidence_indicbert_v2.csv"
) -> pd.DataFrame:
    """
    Given merged SHAP+LIME token importances, compute agreement metrics and
    confidence scores per sentence, then save to CSV.

    Parameters
    ----------
    merged_df : pd.DataFrame
        Output of merge_shap_lime().
    results_dir : str
        Directory where the similarity CSV will be saved.
    out_name : str
        File name for the similarity + confidence CSV.

    Returns
    -------
    similarity_df : pd.DataFrame
        One row per sentence_id with cosine, Pearson, JS and confidence_score/level.
    """

    def _to_prob(x: np.ndarray) -> np.ndarray:
        """Turning signed importance into a probability distribution (for JS)."""
        x = np.abs(x.astype(float))
        if x.sum() == 0:
            return np.ones_like(x) / len(x)
        return x / x.sum()

    def _js_divergence(p: np.ndarray, q: np.ndarray) -> float:
        """Jensen–Shannon divergence between two discrete distributions."""
        m = 0.5 * (p + q)

        def _kl(a, b):
            mask = (a > 0) & (b > 0)
            return np.sum(a[mask] * np.log(a[mask] / b[mask]))

        return 0.5 * _kl(p, m) + 0.5 * _kl(q, m)

    similarity_rows = []

    for sid, group in merged_df.groupby("sentence_id"):
        shap_vals = group["value_shap"].values
        lime_vals = group["value_lime"].values

        # Skipping degenerate cases
        if len(shap_vals) < 2 or np.all(shap_vals == 0) or np.all(lime_vals == 0):
            continue

        # Defining Cosine similarity
        cos = float(
            cosine_similarity(
                shap_vals.reshape(1, -1),
                lime_vals.reshape(1, -1)
            )[0, 0]
        )

        # Defining Pearson correlation
        if np.std(shap_vals) == 0 or np.std(lime_vals) == 0:
            pearson = np.nan
        else:
            pearson = float(np.corrcoef(shap_vals, lime_vals)[0, 1])

        # Defining JS divergence on |values|
        p = _to_prob(shap_vals)
        q = _to_prob(lime_vals)
        js = float(_js_divergence(p, q))

        row0 = group.iloc[0]
        similarity_rows.append({
            "sentence_id": sid,
            "true_label": row0.get("true_label", np.nan),
            "predicted_label": row0.get("predicted_label", np.nan),
            "cosine_similarity": cos,
            "pearson_correlation": pearson,
            "js_divergence": js,
        })

    similarity_df = pd.DataFrame(similarity_rows)
    print("Similarity rows:", len(similarity_df))

    if len(similarity_df) > 0:
        # Filling NaNs in Pearson before combining
        similarity_df["pearson_correlation"] = similarity_df["pearson_correlation"].fillna(0.0)

        similarity_df["confidence_score"] = (
            similarity_df["cosine_similarity"]
            + similarity_df["pearson_correlation"]
            + (1 - similarity_df["js_divergence"])
        ) / 3.0

        similarity_df["confidence_level"] = pd.cut(
            similarity_df["confidence_score"],
            bins=[-np.inf, 0.3, 0.6, np.inf],
            labels=["Low", "Medium", "High"]
        )

        print("\nConfidence distribution:")
        print(similarity_df["confidence_level"].value_counts().sort_index())

        avg_cosine = similarity_df["cosine_similarity"].mean()
        avg_pearson = similarity_df["pearson_correlation"].mean()
        avg_js = similarity_df["js_divergence"].mean()

        print("\nAverage agreement metrics:")
        print(f"  Cosine similarity:   {avg_cosine:.3f}")
        print(f"  Pearson correlation: {avg_pearson:.3f}")
        print(f"  JS divergence:       {avg_js:.3f}")

        out_csv = os.path.join(results_dir, out_name)
        similarity_df.to_csv(out_csv, index=False)
        print(f"\n✅ Saved similarity + confidence to: {out_csv}")
    else:
        print("⚠️ No overlapping tokens between SHAP and LIME; similarity_df is empty.")

    return similarity_df

# %% [markdown]
# # Explainability Analysis

# %%
# Defining a function for explainability analysis on a given number of samples
def explainability_analysis(df, num_samples, shap_results_file_name, lime_results_file_name, explainability_results_file_name):
    # Creating a subset of the datset for the analysis
    explain_subset = get_explainability_subset(df, num_samples)
    explain_subset.head()
    
    # Onbtaining a subset of samples from the dataset
    explain_subset = add_model_predictions(explain_subset, model, tokenizer)
    print(explain_subset.head())
    
    # Running SHAP on the selected subset of data
    shap_results = shap_analysis(explain_subset, text_col="cleaned_text")  

    print("\nSHAP results (head):")
    print(shap_results.head())

    shap_csv_path = os.path.join(RESULTS_DIR,  shap_results_file_name)
    shap_results.to_csv(shap_csv_path, index=False)
    print(f"✅ Saved SHAP token-level results to: {shap_csv_path}")
    
    # Aplplying the LIME analysis function to selected subset of the datset
    lime_results = lime_analysis_indicbert(
    sampled_df=explain_subset,
    text_col="cleaned_text",          
    true_col="labels",
    pred_col="predicted_label",
    save_path=os.path.join(RESULTS_DIR, lime_results_file_name),
    )

    print(lime_results.head())
    
    # Merging the SHAP/LIME results
    merged_file = merge_shap_lime(
    RESULTS_DIR,
    shap_filename= shap_results_file_name,
    lime_filename= lime_results_file_name,
    )
    
    # Calculating SHAP/LIME confidence scores
    similarity_file = compute_shap_lime_similarity(
    merged_df=merged_file,
    results_dir=RESULTS_DIR,
    out_name=  explainability_results_file_name
    )
    
    return

# %% [markdown]
# # For 10 samples

# %%
# Calling the function  for explainability analysis on 10 samples
explainability_analysis(df, 10, "shap_results_10", "lime_results_10", "explainability_results_10")
# Out:
# Selected subset size: 10
# Hate: 5 Non-hate: 5
#                                         cleaned_text  labels  predicted_label  \
# 0  udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिल...       0                0
# 1  'मजहब नहीं सिखाता आपस में बैर रखना' ... यह लाइ...       1                1
# 2  अमेरिकी शोधकर्ताओं का दावा: बिल्लियों को दी जा...       0                0
# 3  कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी...       1                1
# 4  प्रशांत भूषण अवमानना मामले में सुप्रीम कोर्ट आ...       0                0
#
#    actual_label dataset_name categorisation
# 0             0        HASOC       non-hate
# 1             1        HASOC           hate
# 2             0        HASOC       non-hate
# 3             1        HASOC           hate
# 4             0        HASOC       non-hate
# Row 0 | True: 0 | Pred: 0 | Text: udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिली मंजूरी, आपका...
# Row 1 | True: 1 | Pred: 1 | Text: 'मजहब नहीं सिखाता आपस में बैर रखना' ... यह लाइन सिर्फ हिंदुओ...
# Row 2 | True: 0 | Pred: 0 | Text: अमेरिकी शोधकर्ताओं का दावा: बिल्लियों को दी जाने वाली एंटीवा...
# Row 3 | True: 1 | Pred: 1 | Text: कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी जी से हार क्य...
# Row 4 | True: 0 | Pred: 0 | Text: प्रशांत भूषण अवमानना मामले में सुप्रीम कोर्ट आज सुनाएगा फैसल...
# Row 5 | True: 1 | Pred: 1 | Text: ये है बदलता हिन्दुस्तान.. जौनपुर की तस्वीर है ये...अब तो गां...
# Row 6 | True: 0 | Pred: 1 | Text: झारखंड के मुस्लिम चोर की बीबी को सरकारी नौकरी और 5 लाख रुपये...
# Row 7 | True: 1 | Pred: 1 | Text: link बुद्ध नगरी है.. इस वीडियो में देखें हर जगह बुद्ध ही बुद...
# Row 8 | True: 1 | Pred: 1 | Text: देख लो हिन्दुस्ता के लोगो आज तिरंगा जला रहे है साले कल लोगो ...
# Row 9 | True: 0 | Pred: 0 | Text: मुंबई सबसे ज्यादा "टैक्स" भी दे और "जान" भी ? ताल ठोक के...
#
# SHAP results (head):
#    sentence_id    token  value_shap  \
# 0            0  udan-4:    0.002164
# 1            0       ये    0.000705
# 2            0      हैं   -0.001026
# 3            0       78   -0.001074
# 4            0       नए   -0.000747
#
#                                             sentence  true_label  \
# 0  udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिल...           0
# 1  udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिल...           0
# 2  udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिल...           0
# 3  udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिल...           0
# 4  udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिल...           0
#
#    predicted_label
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ✅ Saved SHAP token-level results to: ./indicbert_explainability/shap_results_10
# Row 0 | True: 0 | Pred: 0 | Text: udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिली मंजूरी, आपका...
# Row 1 | True: 1 | Pred: 1 | Text: 'मजहब नहीं सिखाता आपस में बैर रखना' ... यह लाइन सिर्फ हिंदुओ...
# Row 2 | True: 0 | Pred: 0 | Text: अमेरिकी शोधकर्ताओं का दावा: बिल्लियों को दी जाने वाली एंटीवा...
# Row 3 | True: 1 | Pred: 1 | Text: कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी जी से हार क्य...
# Row 4 | True: 0 | Pred: 0 | Text: प्रशांत भूषण अवमानना मामले में सुप्रीम कोर्ट आज सुनाएगा फैसल...
# Row 5 | True: 1 | Pred: 1 | Text: ये है बदलता हिन्दुस्तान.. जौनपुर की तस्वीर है ये...अब तो गां...
# Row 6 | True: 0 | Pred: 1 | Text: झारखंड के मुस्लिम चोर की बीबी को सरकारी नौकरी और 5 लाख रुपये...
# Row 7 | True: 1 | Pred: 1 | Text: link बुद्ध नगरी है.. इस वीडियो में देखें हर जगह बुद्ध ही बुद...
# Row 8 | True: 1 | Pred: 1 | Text: देख लो हिन्दुस्ता के लोगो आज तिरंगा जला रहे है साले कल लोगो ...
# Row 9 | True: 0 | Pred: 0 | Text: मुंबई सबसे ज्यादा "टैक्स" भी दे और "जान" भी ? ताल ठोक के...
# ✅ Saved LIME results to: ./indicbert_explainability/lime_results_10
#    sentence_id    token    value_lime  \
# 0            0  udan-4: -4.715277e-04
# 1            0       ये -1.479466e-04
# 2            0      हैं -2.878355e-04
# 3            0       78  5.056847e-05
# 4            0       नए -8.345709e-07
#
#                                             sentence  true_label  \
# 0  udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिल...           0
# 1  udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिल...           0
# 2  udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिल...           0
# 3  udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिल...           0
# 4  udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिल...           0
#
#    predicted_label
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# SHAP shape: (253, 6)
# LIME shape: (253, 6)
#
# Merged shape: (291, 7)
# Similarity rows: 10
#
# Confidence distribution:
# confidence_level
# Low       2
# Medium    3
# High      5
# Name: count, dtype: int64
#
# Average agreement metrics:
#   Cosine similarity:   0.392
#   Pearson correlation: 0.395
#   JS divergence:       0.136
#
# ✅ Saved similarity + confidence to: ./indicbert_explainability/explainability_results_10

# %% [markdown]
# # For 20 samples

# %%
# Calling the function for explainability analysis on 20 samples
explainability_analysis(df, 20, "shap_results_20", "lime_results_20", "explainability_results_20")
# Out:
# Selected subset size: 20
# Hate: 10 Non-hate: 10
#                                         cleaned_text  labels  predicted_label  \
# 0  कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी...       1                1
# 1      तू कहा अपना झोपड़ा मरवा रही है मादरचोद कूत्ती       0                0
# 2  आप एक साल तक बाहर नहीं जा सकते, ऐसे ही कुल 21 ...       0                0
# 3  'मजहब नहीं सिखाता आपस में बैर रखना' ... यह लाइ...       1                1
# 4  यह हरामि दिल्ली मुसलमान को तालिबानी कह रही है ...       1                1
#
#    actual_label dataset_name categorisation
# 0             1        HASOC           hate
# 1             0        HASOC       non-hate
# 2             0        HASOC       non-hate
# 3             1        HASOC           hate
# 4             1        HASOC           hate
# Row 0 | True: 1 | Pred: 1 | Text: कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी जी से हार क्य...
# Row 1 | True: 0 | Pred: 0 | Text: तू कहा अपना झोपड़ा मरवा रही है मादरचोद कूत्ती...
# Row 2 | True: 0 | Pred: 0 | Text: आप एक साल तक बाहर नहीं जा सकते, ऐसे ही कुल 21 दिशा-निर्देश...
# Row 3 | True: 1 | Pred: 1 | Text: 'मजहब नहीं सिखाता आपस में बैर रखना' ... यह लाइन सिर्फ हिंदुओ...
# Row 4 | True: 1 | Pred: 1 | Text: यह हरामि दिल्ली मुसलमान को तालिबानी कह रही है इसको सही जवाब ...
# Row 5 | True: 1 | Pred: 1 | Text: बेशर्मी तो तुम दिखाते हो हरामखोर,डरा हुआ मुसलमान ही सौ साल प...
# Row 6 | True: 0 | Pred: 0 | Text: मुंबई सबसे ज्यादा "टैक्स" भी दे और "जान" भी ? ताल ठोक के...
# Row 7 | True: 1 | Pred: 1 | Text: देख लो हिन्दुस्ता के लोगो आज तिरंगा जला रहे है साले कल लोगो ...
# Row 8 | True: 0 | Pred: 0 | Text: गांड पे लात मार के नीकाल फेंको बाप बेचे को पार्टी से बहार...
# Row 9 | True: 0 | Pred: 0 | Text: उत्तराखंड के इस जिले में बढ़ता जा रहा कोरोना संक्रमण, पुलिस ...
# Row 10 | True: 0 | Pred: 0 | Text: udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिली मंजूरी, आपका...
# Row 11 | True: 1 | Pred: 1 | Text: ये है बदलता हिन्दुस्तान.. जौनपुर की तस्वीर है ये...अब तो गां...
# Row 12 | True: 1 | Pred: 1 | Text: आतंकवादी हमले के आरोपी साध्वी प्रज्ञा_ठाकुर का संसद पहुंचना ...
# Row 13 | True: 0 | Pred: 1 | Text: वो कुछ लोग जो मुल्ले है वो रिश्ते में तेरे बाप लगते है समझा ...
# Row 14 | True: 1 | Pred: 1 | Text: link बुद्ध नगरी है.. इस वीडियो में देखें हर जगह बुद्ध ही बुद...
# Row 15 | True: 0 | Pred: 0 | Text: प्रशांत भूषण अवमानना मामले में सुप्रीम कोर्ट आज सुनाएगा फैसल...
# Row 16 | True: 1 | Pred: 1 | Text: ट्रम्प हमारे लोकतंत्र के लिए खतरा हैं! इसके अलावा, अगर मेरा ...
# Row 17 | True: 0 | Pred: 0 | Text: अमेरिकी शोधकर्ताओं का दावा: बिल्लियों को दी जाने वाली एंटीवा...
# Row 18 | True: 0 | Pred: 1 | Text: झारखंड के मुस्लिम चोर की बीबी को सरकारी नौकरी और 5 लाख रुपये...
# Row 19 | True: 1 | Pred: 1 | Text: हिंदुओं की समस्या का मूल कारन हिन्दुओं का चुप रहना है, उसको ...
#
# SHAP results (head):
#    sentence_id      token  value_shap  \
# 0            0  कांग्रेसी    0.289201
# 1            0       चमचे   -0.021098
# 2            0          -   -0.061292
# 3            0      राहुल    0.030092
# 4            0      गांधी    0.074789
#
#                                             sentence  true_label  \
# 0  कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी...           1
# 1  कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी...           1
# 2  कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी...           1
# 3  कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी...           1
# 4  कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी...           1
#
#    predicted_label
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ✅ Saved SHAP token-level results to: ./indicbert_explainability/shap_results_20
# Row 0 | True: 1 | Pred: 1 | Text: कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी जी से हार क्य...
# Row 1 | True: 0 | Pred: 0 | Text: तू कहा अपना झोपड़ा मरवा रही है मादरचोद कूत्ती...
# Row 2 | True: 0 | Pred: 0 | Text: आप एक साल तक बाहर नहीं जा सकते, ऐसे ही कुल 21 दिशा-निर्देश...
# Row 3 | True: 1 | Pred: 1 | Text: 'मजहब नहीं सिखाता आपस में बैर रखना' ... यह लाइन सिर्फ हिंदुओ...
# Row 4 | True: 1 | Pred: 1 | Text: यह हरामि दिल्ली मुसलमान को तालिबानी कह रही है इसको सही जवाब ...
# Row 5 | True: 1 | Pred: 1 | Text: बेशर्मी तो तुम दिखाते हो हरामखोर,डरा हुआ मुसलमान ही सौ साल प...
# Row 6 | True: 0 | Pred: 0 | Text: मुंबई सबसे ज्यादा "टैक्स" भी दे और "जान" भी ? ताल ठोक के...
# Row 7 | True: 1 | Pred: 1 | Text: देख लो हिन्दुस्ता के लोगो आज तिरंगा जला रहे है साले कल लोगो ...
# Row 8 | True: 0 | Pred: 0 | Text: गांड पे लात मार के नीकाल फेंको बाप बेचे को पार्टी से बहार...
# Row 9 | True: 0 | Pred: 0 | Text: उत्तराखंड के इस जिले में बढ़ता जा रहा कोरोना संक्रमण, पुलिस ...
# Row 10 | True: 0 | Pred: 0 | Text: udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिली मंजूरी, आपका...
# Row 11 | True: 1 | Pred: 1 | Text: ये है बदलता हिन्दुस्तान.. जौनपुर की तस्वीर है ये...अब तो गां...
# Row 12 | True: 1 | Pred: 1 | Text: आतंकवादी हमले के आरोपी साध्वी प्रज्ञा_ठाकुर का संसद पहुंचना ...
# Row 13 | True: 0 | Pred: 1 | Text: वो कुछ लोग जो मुल्ले है वो रिश्ते में तेरे बाप लगते है समझा ...
# Row 14 | True: 1 | Pred: 1 | Text: link बुद्ध नगरी है.. इस वीडियो में देखें हर जगह बुद्ध ही बुद...
# Row 15 | True: 0 | Pred: 0 | Text: प्रशांत भूषण अवमानना मामले में सुप्रीम कोर्ट आज सुनाएगा फैसल...
# Row 16 | True: 1 | Pred: 1 | Text: ट्रम्प हमारे लोकतंत्र के लिए खतरा हैं! इसके अलावा, अगर मेरा ...
# Row 17 | True: 0 | Pred: 0 | Text: अमेरिकी शोधकर्ताओं का दावा: बिल्लियों को दी जाने वाली एंटीवा...
# Row 18 | True: 0 | Pred: 1 | Text: झारखंड के मुस्लिम चोर की बीबी को सरकारी नौकरी और 5 लाख रुपये...
# Row 19 | True: 1 | Pred: 1 | Text: हिंदुओं की समस्या का मूल कारन हिन्दुओं का चुप रहना है, उसको ...
# ✅ Saved LIME results to: ./indicbert_explainability/lime_results_20
#    sentence_id      token  value_lime  \
# 0            0  कांग्रेसी    0.336199
# 1            0       चमचे    0.101720
# 2            0          -   -0.025363
# 3            0      राहुल   -0.000143
# 4            0      गांधी    0.046290
#
#                                             sentence  true_label  \
# 0  कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी...           1
# 1  कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी...           1
# 2  कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी...           1
# 3  कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी...           1
# 4  कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी...           1
#
#    predicted_label
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# SHAP shape: (456, 6)
# LIME shape: (456, 6)
#
# Merged shape: (526, 7)
# Similarity rows: 20
#
# Confidence distribution:
# confidence_level
# Low        7
# Medium     3
# High      10
# Name: count, dtype: int64
#
# Average agreement metrics:
#   Cosine similarity:   0.327
#   Pearson correlation: 0.311
#   JS divergence:       0.139
#
# ✅ Saved similarity + confidence to: ./indicbert_explainability/explainability_results_20

# %% [markdown]
# # For 50 samples

# %%
# Calling the function
explainability_analysis(df, 50, "shap_results_50", "lime_results_50", "explainability_results_50")
# Out:
# Selected subset size: 50
# Hate: 25 Non-hate: 25
#                                         cleaned_text  labels  predicted_label  \
# 0  जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरख...       1                1
# 1  कंगना को अगर मुख्यमंत्री को 'तू' बोलने पर y+ स...       0                0
# 2  आप एक साल तक बाहर नहीं जा सकते, ऐसे ही कुल 21 ...       0                0
# 3  और जिसका अर्थ समझ में आया, उसमे पता चला होगा क...       0                0
# 4  हिंदुस्तान के अंदर हिंदुओं का ही धर्मपरिवर्तन ...       1                1
#
#    actual_label dataset_name categorisation
# 0             1        HASOC           hate
# 1             0        HASOC       non-hate
# 2             0        HASOC       non-hate
# 3             0        HASOC       non-hate
# 4             1        HASOC           hate
# Row 0 | True: 1 | Pred: 1 | Text: जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरखपुर का कुछ नही...
# Row 1 | True: 0 | Pred: 0 | Text: कंगना को अगर मुख्यमंत्री को 'तू' बोलने पर y+ सुरक्षा दी जाती...
# Row 2 | True: 0 | Pred: 0 | Text: आप एक साल तक बाहर नहीं जा सकते, ऐसे ही कुल 21 दिशा-निर्देश...
# Row 3 | True: 0 | Pred: 0 | Text: और जिसका अर्थ समझ में आया, उसमे पता चला होगा की उनके पूर्वजो...
# Row 4 | True: 1 | Pred: 1 | Text: हिंदुस्तान के अंदर हिंदुओं का ही धर्मपरिवर्तन हिंदू बेटियों ...
# Row 5 | True: 0 | Pred: 0 | Text: स्वतंत्रता संग्राम की प्रथम महिला नायिका रानी लक्ष्मीबाई जी ...
# Row 6 | True: 0 | Pred: 0 | Text: मुंबई सबसे ज्यादा "टैक्स" भी दे और "जान" भी ? ताल ठोक के...
# Row 7 | True: 0 | Pred: 0 | Text: अमेरिकी शोधकर्ताओं का दावा: बिल्लियों को दी जाने वाली एंटीवा...
# Row 8 | True: 0 | Pred: 0 | Text: तू कहा अपना झोपड़ा मरवा रही है मादरचोद कूत्ती...
# Row 9 | True: 1 | Pred: 0 | Text: दिल्ली में आयुष्मान भारत योजना को रोक कर मुख्यमंत्री केजरीवा...
# Row 10 | True: 1 | Pred: 0 | Text: tay ho gaya bhaiya ji ki kitne mai seat bechni hai congress ...
# Row 11 | True: 1 | Pred: 1 | Text: link बुद्ध नगरी है.. इस वीडियो में देखें हर जगह बुद्ध ही बुद...
# Row 12 | True: 0 | Pred: 0 | Text: पालतू जानवरों जैसे बिल्लियों या कुत्तों द्वारा covid19 इंसान...
# Row 13 | True: 1 | Pred: 1 | Text: यह हरामि दिल्ली मुसलमान को तालिबानी कह रही है इसको सही जवाब ...
# Row 14 | True: 1 | Pred: 1 | Text: देख लो हिन्दुस्ता के लोगो आज तिरंगा जला रहे है साले कल लोगो ...
# Row 15 | True: 1 | Pred: 1 | Text: हिंदुओं की समस्या का मूल कारन हिन्दुओं का चुप रहना है, उसको ...
# Row 16 | True: 0 | Pred: 0 | Text: अबे कमिने राज्यसभा में इस तरह के कार्य को गुंडागर्दी कहते है...
# Row 17 | True: 0 | Pred: 0 | Text: अखबार की सुर्खी - कोर्ट की कसौटी पर खरा साबित हुआ pm केअर फण...
# Row 18 | True: 0 | Pred: 0 | Text: नीतीश कुमार ने जेडीयू के वर्चुअल सम्मेलन में सुशांत सिंह राज...
# Row 19 | True: 1 | Pred: 0 | Text: संजय सिंह मादरचोद की औलाद है साला कुत्ता है...
# Row 20 | True: 1 | Pred: 1 | Text: आतंकवादी हमले के आरोपी साध्वी प्रज्ञा_ठाकुर का संसद पहुंचना ...
# Row 21 | True: 1 | Pred: 1 | Text: भारत में मुस्लिमों द्वारा सोशल डिस्टेंसिंग को फॉलो नहीं किया...
# Row 22 | True: 1 | Pred: 1 | Text: आज सरकार कश्मीर समस्या पर तो बहस करना चाहती है,लेकिन evm समस...
# Row 23 | True: 0 | Pred: 1 | Text: वो कुछ लोग जो मुल्ले है वो रिश्ते में तेरे बाप लगते है समझा ...
# Row 24 | True: 0 | Pred: 0 | Text: उत्तराखंड के इस जिले में बढ़ता जा रहा कोरोना संक्रमण, पुलिस ...
# Row 25 | True: 1 | Pred: 1 | Text: कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी जी से हार क्य...
# Row 26 | True: 0 | Pred: 0 | Text: मुख्य आर्थिक सलाहकार ने कहा-देश में इस वर्ष अप्रैल से जून की...
# Row 27 | True: 0 | Pred: 0 | Text: प्रशांत भूषण अवमानना मामले में सुप्रीम कोर्ट आज सुनाएगा फैसल...
# Row 28 | True: 0 | Pred: 0 | Text: गांड पे लात मार के नीकाल फेंको बाप बेचे को पार्टी से बहार...
# Row 29 | True: 1 | Pred: 1 | Text: बेशर्मी तो तुम दिखाते हो हरामखोर,डरा हुआ मुसलमान ही सौ साल प...
# Row 30 | True: 0 | Pred: 1 | Text: झारखंड के मुस्लिम चोर की बीबी को सरकारी नौकरी और 5 लाख रुपये...
# Row 31 | True: 1 | Pred: 1 | Text: ला़कडाउन की वजह से शादीशुदा महिलाओं की नौकरानी जैसी हैसियत ह...
# Row 32 | True: 0 | Pred: 0 | Text: मेहबूबा शर्म कर रंडी हरे रंग वाली छिनाल कोई कुछ भी...
# Row 33 | True: 1 | Pred: 1 | Text: 'मजहब नहीं सिखाता आपस में बैर रखना' ... यह लाइन सिर्फ हिंदुओ...
# Row 34 | True: 1 | Pred: 1 | Text: तेरे जैसी हर रोज़ बीना वजह भोंकनेवाली कुतिया, कुत्ते की मौत ...
# Row 35 | True: 1 | Pred: 1 | Text: ये है बदलता हिन्दुस्तान.. जौनपुर की तस्वीर है ये...अब तो गां...
# Row 36 | True: 0 | Pred: 0 | Text: ब्रिटेन के प्रधानमंत्री बोरिस जॉनसन ने यूरोपीय संघ को व्यापा...
# Row 37 | True: 0 | Pred: 0 | Text: सुशांत केस में एक और ड्रग पेडलर गिरफ्तार sushantsinghrajputd...
# Row 38 | True: 1 | Pred: 0 | Text: हमे अपना नारा लगवाने के लिए किसी को मारने की जरूरत नहीं ! बो...
# Row 39 | True: 0 | Pred: 0 | Text: sureshraina के ट्वीट के बाद पंजाब पुलिस का बड़ा फैसला link...
# Row 40 | True: 1 | Pred: 1 | Text: गेंडा स्वामी कुत्ते की मौत मर गया साला ये घटना कब तक काल्पनि...
# Row 41 | True: 1 | Pred: 1 | Text: ये तो साला नेता कम और छक्का ज्यादा लगता है!🤔😂 संजय_सिंह_गुंड...
# Row 42 | True: 1 | Pred: 1 | Text: अबे चरसी गांजाटी 'तेरी औकात नाही साले भडवे डूब मर काही जाके...
# Row 43 | True: 0 | Pred: 0 | Text: सैफ अली खान एक सांस में तीन बार अलग अलग टोन में wow! wow! wo...
# Row 44 | True: 1 | Pred: 0 | Text: भड़वा गिरी कर 2 करोड क्युं?? 20 करोड़ भी हो जाएंगे......
# Row 45 | True: 1 | Pred: 1 | Text: ट्रम्प हमारे लोकतंत्र के लिए खतरा हैं! इसके अलावा, अगर मेरा ...
# Row 46 | True: 0 | Pred: 0 | Text: संसद लोकतंत्र का मंदिर ही क्यों ? चर्च, गुरुद्वारा या मस्जिद...
# Row 47 | True: 1 | Pred: 1 | Text: rt कंगना की जगह अगर सलमान भाई भाजपा में अा गए होते, तो भाजपा...
# Row 48 | True: 0 | Pred: 0 | Text: udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिली मंजूरी, आपका...
# Row 49 | True: 0 | Pred: 0 | Text: भेनचोद जहाँ दिखाया जा रहा वहां क्यों नहीं बोल रहा गांड फटती ...
#
# SHAP results (head):
#    sentence_id    token  value_shap  \
# 0            0       जब   -0.057268
# 1            0       तक    0.024276
# 2            0  गोरखपुर    0.123331
# 3            0      में    0.082396
# 4            0   बीजेपी    0.361048
#
#                                             sentence  true_label  \
# 0  जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरख...           1
# 1  जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरख...           1
# 2  जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरख...           1
# 3  जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरख...           1
# 4  जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरख...           1
#
#    predicted_label
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ✅ Saved SHAP token-level results to: ./indicbert_explainability/shap_results_50
# Row 0 | True: 1 | Pred: 1 | Text: जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरखपुर का कुछ नही...
# Row 1 | True: 0 | Pred: 0 | Text: कंगना को अगर मुख्यमंत्री को 'तू' बोलने पर y+ सुरक्षा दी जाती...
# Row 2 | True: 0 | Pred: 0 | Text: आप एक साल तक बाहर नहीं जा सकते, ऐसे ही कुल 21 दिशा-निर्देश...
# Row 3 | True: 0 | Pred: 0 | Text: और जिसका अर्थ समझ में आया, उसमे पता चला होगा की उनके पूर्वजो...
# Row 4 | True: 1 | Pred: 1 | Text: हिंदुस्तान के अंदर हिंदुओं का ही धर्मपरिवर्तन हिंदू बेटियों ...
# Row 5 | True: 0 | Pred: 0 | Text: स्वतंत्रता संग्राम की प्रथम महिला नायिका रानी लक्ष्मीबाई जी ...
# Row 6 | True: 0 | Pred: 0 | Text: मुंबई सबसे ज्यादा "टैक्स" भी दे और "जान" भी ? ताल ठोक के...
# Row 7 | True: 0 | Pred: 0 | Text: अमेरिकी शोधकर्ताओं का दावा: बिल्लियों को दी जाने वाली एंटीवा...
# Row 8 | True: 0 | Pred: 0 | Text: तू कहा अपना झोपड़ा मरवा रही है मादरचोद कूत्ती...
# Row 9 | True: 1 | Pred: 0 | Text: दिल्ली में आयुष्मान भारत योजना को रोक कर मुख्यमंत्री केजरीवा...
# Row 10 | True: 1 | Pred: 0 | Text: tay ho gaya bhaiya ji ki kitne mai seat bechni hai congress ...
# Row 11 | True: 1 | Pred: 1 | Text: link बुद्ध नगरी है.. इस वीडियो में देखें हर जगह बुद्ध ही बुद...
# Row 12 | True: 0 | Pred: 0 | Text: पालतू जानवरों जैसे बिल्लियों या कुत्तों द्वारा covid19 इंसान...
# Row 13 | True: 1 | Pred: 1 | Text: यह हरामि दिल्ली मुसलमान को तालिबानी कह रही है इसको सही जवाब ...
# Row 14 | True: 1 | Pred: 1 | Text: देख लो हिन्दुस्ता के लोगो आज तिरंगा जला रहे है साले कल लोगो ...
# Row 15 | True: 1 | Pred: 1 | Text: हिंदुओं की समस्या का मूल कारन हिन्दुओं का चुप रहना है, उसको ...
# Row 16 | True: 0 | Pred: 0 | Text: अबे कमिने राज्यसभा में इस तरह के कार्य को गुंडागर्दी कहते है...
# Row 17 | True: 0 | Pred: 0 | Text: अखबार की सुर्खी - कोर्ट की कसौटी पर खरा साबित हुआ pm केअर फण...
# Row 18 | True: 0 | Pred: 0 | Text: नीतीश कुमार ने जेडीयू के वर्चुअल सम्मेलन में सुशांत सिंह राज...
# Row 19 | True: 1 | Pred: 0 | Text: संजय सिंह मादरचोद की औलाद है साला कुत्ता है...
# Row 20 | True: 1 | Pred: 1 | Text: आतंकवादी हमले के आरोपी साध्वी प्रज्ञा_ठाकुर का संसद पहुंचना ...
# Row 21 | True: 1 | Pred: 1 | Text: भारत में मुस्लिमों द्वारा सोशल डिस्टेंसिंग को फॉलो नहीं किया...
# Row 22 | True: 1 | Pred: 1 | Text: आज सरकार कश्मीर समस्या पर तो बहस करना चाहती है,लेकिन evm समस...
# Row 23 | True: 0 | Pred: 1 | Text: वो कुछ लोग जो मुल्ले है वो रिश्ते में तेरे बाप लगते है समझा ...
# Row 24 | True: 0 | Pred: 0 | Text: उत्तराखंड के इस जिले में बढ़ता जा रहा कोरोना संक्रमण, पुलिस ...
# Row 25 | True: 1 | Pred: 1 | Text: कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी जी से हार क्य...
# Row 26 | True: 0 | Pred: 0 | Text: मुख्य आर्थिक सलाहकार ने कहा-देश में इस वर्ष अप्रैल से जून की...
# Row 27 | True: 0 | Pred: 0 | Text: प्रशांत भूषण अवमानना मामले में सुप्रीम कोर्ट आज सुनाएगा फैसल...
# Row 28 | True: 0 | Pred: 0 | Text: गांड पे लात मार के नीकाल फेंको बाप बेचे को पार्टी से बहार...
# Row 29 | True: 1 | Pred: 1 | Text: बेशर्मी तो तुम दिखाते हो हरामखोर,डरा हुआ मुसलमान ही सौ साल प...
# Row 30 | True: 0 | Pred: 1 | Text: झारखंड के मुस्लिम चोर की बीबी को सरकारी नौकरी और 5 लाख रुपये...
# Row 31 | True: 1 | Pred: 1 | Text: ला़कडाउन की वजह से शादीशुदा महिलाओं की नौकरानी जैसी हैसियत ह...
# Row 32 | True: 0 | Pred: 0 | Text: मेहबूबा शर्म कर रंडी हरे रंग वाली छिनाल कोई कुछ भी...
# Row 33 | True: 1 | Pred: 1 | Text: 'मजहब नहीं सिखाता आपस में बैर रखना' ... यह लाइन सिर्फ हिंदुओ...
# Row 34 | True: 1 | Pred: 1 | Text: तेरे जैसी हर रोज़ बीना वजह भोंकनेवाली कुतिया, कुत्ते की मौत ...
# Row 35 | True: 1 | Pred: 1 | Text: ये है बदलता हिन्दुस्तान.. जौनपुर की तस्वीर है ये...अब तो गां...
# Row 36 | True: 0 | Pred: 0 | Text: ब्रिटेन के प्रधानमंत्री बोरिस जॉनसन ने यूरोपीय संघ को व्यापा...
# Row 37 | True: 0 | Pred: 0 | Text: सुशांत केस में एक और ड्रग पेडलर गिरफ्तार sushantsinghrajputd...
# Row 38 | True: 1 | Pred: 0 | Text: हमे अपना नारा लगवाने के लिए किसी को मारने की जरूरत नहीं ! बो...
# Row 39 | True: 0 | Pred: 0 | Text: sureshraina के ट्वीट के बाद पंजाब पुलिस का बड़ा फैसला link...
# Row 40 | True: 1 | Pred: 1 | Text: गेंडा स्वामी कुत्ते की मौत मर गया साला ये घटना कब तक काल्पनि...
# Row 41 | True: 1 | Pred: 1 | Text: ये तो साला नेता कम और छक्का ज्यादा लगता है!🤔😂 संजय_सिंह_गुंड...
# Row 42 | True: 1 | Pred: 1 | Text: अबे चरसी गांजाटी 'तेरी औकात नाही साले भडवे डूब मर काही जाके...
# Row 43 | True: 0 | Pred: 0 | Text: सैफ अली खान एक सांस में तीन बार अलग अलग टोन में wow! wow! wo...
# Row 44 | True: 1 | Pred: 0 | Text: भड़वा गिरी कर 2 करोड क्युं?? 20 करोड़ भी हो जाएंगे......
# Row 45 | True: 1 | Pred: 1 | Text: ट्रम्प हमारे लोकतंत्र के लिए खतरा हैं! इसके अलावा, अगर मेरा ...
# Row 46 | True: 0 | Pred: 0 | Text: संसद लोकतंत्र का मंदिर ही क्यों ? चर्च, गुरुद्वारा या मस्जिद...
# Row 47 | True: 1 | Pred: 1 | Text: rt कंगना की जगह अगर सलमान भाई भाजपा में अा गए होते, तो भाजपा...
# Row 48 | True: 0 | Pred: 0 | Text: udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिली मंजूरी, आपका...
# Row 49 | True: 0 | Pred: 0 | Text: भेनचोद जहाँ दिखाया जा रहा वहां क्यों नहीं बोल रहा गांड फटती ...
# ✅ Saved LIME results to: ./indicbert_explainability/lime_results_50
#    sentence_id    token  value_lime  \
# 0            0       जब    0.016407
# 1            0       तक    0.015623
# 2            0  गोरखपुर    0.141042
# 3            0      में    0.067593
# 4            0   बीजेपी    0.413146
#
#                                             sentence  true_label  \
# 0  जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरख...           1
# 1  जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरख...           1
# 2  जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरख...           1
# 3  जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरख...           1
# 4  जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरख...           1
#
#    predicted_label
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# SHAP shape: (1061, 6)
# LIME shape: (1061, 6)
#
# Merged shape: (1235, 7)
# Similarity rows: 50
#
# Confidence distribution:
# confidence_level
# Low       26
# Medium     6
# High      18
# Name: count, dtype: int64
#
# Average agreement metrics:
#   Cosine similarity:   0.123
#   Pearson correlation: 0.111
#   JS divergence:       0.149
#
# ✅ Saved similarity + confidence to: ./indicbert_explainability/explainability_results_50

# %% [markdown]
# # For 100 samples

# %%
# Calling the function
explainability_analysis(df, 100, "shap_results_100", "lime_results_100", "explainability_results_100")
# Out:
# Selected subset size: 100
# Hate: 50 Non-hate: 50
#                                         cleaned_text  labels  predicted_label  \
# 0  देश में कोविड-19 से स्‍वस्‍थ होने वालों की दर ...       0                0
# 1  udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिल...       0                0
# 2  और जिसका अर्थ समझ में आया, उसमे पता चला होगा क...       0                0
# 3  टीवी पर धार्मिक विवादों पर बहस दिखाने वाले पत्...       1                1
# 4  aap to pura family ko le.dube bhaiya ji ....bu...       1                1
#
#    actual_label dataset_name categorisation
# 0             0        HASOC       non-hate
# 1             0        HASOC       non-hate
# 2             0        HASOC       non-hate
# 3             1        HASOC           hate
# 4             1        HASOC           hate
# Row 0 | True: 0 | Pred: 0 | Text: देश में कोविड-19 से स्‍वस्‍थ होने वालों की दर बढ़कर 76.94 प्...
# Row 1 | True: 0 | Pred: 0 | Text: udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिली मंजूरी, आपका...
# Row 2 | True: 0 | Pred: 0 | Text: और जिसका अर्थ समझ में आया, उसमे पता चला होगा की उनके पूर्वजो...
# Row 3 | True: 1 | Pred: 1 | Text: टीवी पर धार्मिक विवादों पर बहस दिखाने वाले पत्रकार जिम्मेवार...
# Row 4 | True: 1 | Pred: 1 | Text: aap to pura family ko le.dube bhaiya ji ....but koe nhi hm s...
# Row 5 | True: 1 | Pred: 1 | Text: कौन कह रहा है प्रदेश में भर्ती प्रकिया रुकी है?? हो तो रही ह...
# Row 6 | True: 1 | Pred: 1 | Text: ये तो साला नेता कम और छक्का ज्यादा लगता है!🤔😂 संजय_सिंह_गुंड...
# Row 7 | True: 0 | Pred: 0 | Text: amitshahhealthupdate: अमित शाह को एम्स से मिली छुट्टी, इलाज ...
# Row 8 | True: 1 | Pred: 1 | Text: गेंडा स्वामी कुत्ते की मौत मर गया साला ये घटना कब तक काल्पनि...
# Row 9 | True: 1 | Pred: 1 | Text: कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी जी से हार क्य...
# Row 10 | True: 1 | Pred: 1 | Text: अबे चरसी गांजाटी 'तेरी औकात नाही साले भडवे डूब मर काही जाके...
# Row 11 | True: 1 | Pred: 1 | Text: उद्धव ठाकरे शिवसेना को उसी ऊंचाई पर ले जाना चाहता हैं! जहाँ ...
# Row 12 | True: 0 | Pred: 0 | Text: स्वतंत्रता संग्राम की प्रथम महिला नायिका रानी लक्ष्मीबाई जी ...
# Row 13 | True: 1 | Pred: 1 | Text: rt प्राइवेट नौकरी करने वाले लड़के को अपने लिये लड़की ढूँढना ...
# Row 14 | True: 0 | Pred: 0 | Text: 74वें स्वतंत्रता दिवस के पावन अवसर पर... link...
# Row 15 | True: 1 | Pred: 1 | Text: link बुद्ध नगरी है.. इस वीडियो में देखें हर जगह बुद्ध ही बुद...
# Row 16 | True: 0 | Pred: 0 | Text: ने सोनिया गाँधी को फोन किया और बोला मैं काँग्रेस अध्यक्ष पद ...
# Row 17 | True: 0 | Pred: 0 | Text: फ्लिपकार्ट होलसेल ने किराना दुकानदारों को सेवाएं देना किया श...
# Row 18 | True: 1 | Pred: 0 | Text: tay ho gaya bhaiya ji ki kitne mai seat bechni hai congress ...
# Row 19 | True: 1 | Pred: 1 | Text: विजयमालिया ललितमोदी नीरवमोदी आसारामबापू बाबारामरहिम पर कोई ह...
# Row 20 | True: 0 | Pred: 0 | Text: आप एक साल तक बाहर नहीं जा सकते, ऐसे ही कुल 21 दिशा-निर्देश...
# Row 21 | True: 0 | Pred: 0 | Text: सेफ माने गए म्यूचुअल फंड भी दे रहे घाटा, आम निवेशक हो रहे नि...
# Row 22 | True: 1 | Pred: 1 | Text: इनके बापने कभी खेती नहीं कि होगी... सरकार तलवे भी चाटेगी इसक...
# Row 23 | True: 1 | Pred: 1 | Text: देखो ये कुतिया पुरी तरह से पगलागयी है यीससे बडा सबुत और क्या...
# Row 24 | True: 0 | Pred: 0 | Text: मुख्य आर्थिक सलाहकार ने कहा-देश में इस वर्ष अप्रैल से जून की...
# Row 25 | True: 1 | Pred: 0 | Text: संजय सिंह मादरचोद की औलाद है साला कुत्ता है...
# Row 26 | True: 1 | Pred: 1 | Text: ये भी हिन्दू रंडी है जो खुद उस कटवे से हमबिस्तरी को गयी है,व...
# Row 27 | True: 0 | Pred: 0 | Text: नहीं रहे भारत के पूर्व राष्ट्रपति प्रणब मुखर्जी pranabmukher...
# Row 28 | True: 1 | Pred: 1 | Text: आतंकवादी हमले के आरोपी साध्वी प्रज्ञा_ठाकुर का संसद पहुंचना ...
# Row 29 | True: 0 | Pred: 0 | Text: नीतीश कुमार ने जेडीयू के वर्चुअल सम्मेलन में सुशांत सिंह राज...
# Row 30 | True: 1 | Pred: 1 | Text: ला़कडाउन की वजह से शादीशुदा महिलाओं की नौकरानी जैसी हैसियत ह...
# Row 31 | True: 1 | Pred: 0 | Text: ये क्या है ,आप लोग क्या कर रहे है ,*bjp विधायक अनिल* *उपाध्य...
# Row 32 | True: 0 | Pred: 0 | Text: जिहाद, आतंकवाद, पत्थरबाज, भारत विरोधी नारे, पाकिस्तान समर्थक...
# Row 33 | True: 1 | Pred: 0 | Text: दिल्ली में दो समुदायों को कौन लड़ाना चाहता है? dangal पूरा क...
# Row 34 | True: 0 | Pred: 0 | Text: आज 30 jun 19 ko मैंने एक ‘योगा एंड हीलिंग सेंटर’ का शुभारम्भ...
# Row 35 | True: 1 | Pred: 1 | Text: बेशर्मी तो तुम दिखाते हो हरामखोर,डरा हुआ मुसलमान ही सौ साल प...
# Row 36 | True: 0 | Pred: 0 | Text: अबे कमिने राज्यसभा में इस तरह के कार्य को गुंडागर्दी कहते है...
# Row 37 | True: 0 | Pred: 0 | Text: sureshraina के ट्वीट के बाद पंजाब पुलिस का बड़ा फैसला link...
# Row 38 | True: 1 | Pred: 1 | Text: माननीय सांसद ने "जय हिन्द" और "जय भीम" भी कहा था, लेकिन आपको...
# Row 39 | True: 1 | Pred: 1 | Text: भारत में मुस्लिमों द्वारा सोशल डिस्टेंसिंग को फॉलो नहीं किया...
# Row 40 | True: 1 | Pred: 0 | Text: प्रधानमंत्री आवास योजना के तहत 30 लाख से अधिक आवास निर्मित उ...
# Row 41 | True: 1 | Pred: 1 | Text: rt अपनी औकात में रहो पाकिस्तान जितनी तुम्हारे यहाँ सरकारी कम...
# Row 42 | True: 1 | Pred: 1 | Text: ट्रम्प हमारे लोकतंत्र के लिए खतरा हैं! इसके अलावा, अगर मेरा ...
# Row 43 | True: 0 | Pred: 0 | Text: उत्तराखंड की जनता इस बार आम आदमी पार्टी के साथ मिलकर अपने अध...
# Row 44 | True: 1 | Pred: 1 | Text: इतना गुंडा गर्दी करने के बाद ठाकरे कहता है 🤔 हमारी खामोशी को...
# Row 45 | True: 1 | Pred: 0 | Text: दिल्ली में आयुष्मान भारत योजना को रोक कर मुख्यमंत्री केजरीवा...
# Row 46 | True: 0 | Pred: 0 | Text: समाजवादी की पहचान ही संघर्ष है जय समाजवाद...
# Row 47 | True: 1 | Pred: 1 | Text: rt केजरीवाल की आंखे 🙄 भर आईं और बोले मेरे से ज्यादा गाली खान...
# Row 48 | True: 0 | Pred: 0 | Text: पालतू जानवरों जैसे बिल्लियों या कुत्तों द्वारा covid19 इंसान...
# Row 49 | True: 1 | Pred: 1 | Text: जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरखपुर का कुछ नही...
# Row 50 | True: 1 | Pred: 1 | Text: आज सरकार कश्मीर समस्या पर तो बहस करना चाहती है,लेकिन evm समस...
# Row 51 | True: 1 | Pred: 1 | Text: देख लो हिन्दुस्ता के लोगो आज तिरंगा जला रहे है साले कल लोगो ...
# Row 52 | True: 1 | Pred: 1 | Text: हिंदुस्तान के अंदर हिंदुओं का ही धर्मपरिवर्तन हिंदू बेटियों ...
# Row 53 | True: 1 | Pred: 1 | Text: अभिनेत्री जायरा ने "इस्लाम में अभिनय हराम" बता फिल्में छोड़ी...
# Row 54 | True: 1 | Pred: 1 | Text: यह हरामि दिल्ली मुसलमान को तालिबानी कह रही है इसको सही जवाब ...
# Row 55 | True: 0 | Pred: 0 | Text: biharelection: बिहार चुनाव के लिए rjd का हेडक्वार्टर बना rim...
# Row 56 | True: 1 | Pred: 1 | Text: हिंदुओं की समस्या का मूल कारन हिन्दुओं का चुप रहना है, उसको ...
# Row 57 | True: 0 | Pred: 0 | Text: कंगना को अगर मुख्यमंत्री को 'तू' बोलने पर y+ सुरक्षा दी जाती...
# Row 58 | True: 1 | Pred: 1 | Text: आर्मी में चमचा गिरी की परंपरा को इसने शुरू किया है । सत्ता क...
# Row 59 | True: 0 | Pred: 0 | Text: राष्टीय अध्यक्ष जी निवेदन है सपा पार्टी में हर समाज के लोगों...
# Row 60 | True: 0 | Pred: 0 | Text: उत्तराखंड के इस जिले में बढ़ता जा रहा कोरोना संक्रमण, पुलिस ...
# Row 61 | True: 0 | Pred: 0 | Text: साला समझ मे नही आता🙄 मुहल्ले के बच्चों को नॉटी कैसे,बोलू संज...
# Row 62 | True: 0 | Pred: 1 | Text: झारखंड के मुस्लिम चोर की बीबी को सरकारी नौकरी और 5 लाख रुपये...
# Row 63 | True: 1 | Pred: 0 | Text: और ये काम कौन करेगा? आप लोग रिपोर्टिंग तो करते नहीं राजनीति ...
# Row 64 | True: 0 | Pred: 0 | Text: अमेरिकी शोधकर्ताओं का दावा: बिल्लियों को दी जाने वाली एंटीवा...
# Row 65 | True: 0 | Pred: 0 | Text: संसद लोकतंत्र का मंदिर ही क्यों ? चर्च, गुरुद्वारा या मस्जिद...
# Row 66 | True: 1 | Pred: 1 | Text: मोदी जी ने इतना पुख़्ता काम कर दिया है कि अगली बार जो भी सत्...
# Row 67 | True: 0 | Pred: 0 | Text: ब्रिटेन के प्रधानमंत्री बोरिस जॉनसन ने यूरोपीय संघ को व्यापा...
# Row 68 | True: 0 | Pred: 0 | Text: मेहबूबा शर्म कर रंडी हरे रंग वाली छिनाल कोई कुछ भी...
# Row 69 | True: 0 | Pred: 0 | Text: सदर पर हमला, मलखान में भर्ती अल्लाह पाक जल्द सिफा अताह फ़रमा...
# Row 70 | True: 0 | Pred: 0 | Text: कन्हैया_कुमार के खिलाफ कोई भी देश द्रोह का सबूत नहीं होने के...
# Row 71 | True: 1 | Pred: 1 | Text: चुप mc कहीं का, अनपढ़, गंवार कमीना, हरामखोर।...
# Row 72 | True: 0 | Pred: 0 | Text: गांड पे लात मार के नीकाल फेंको बाप बेचे को पार्टी से बहार...
# Row 73 | True: 1 | Pred: 1 | Text: rt तुम रोक ना पाओगे वह तूफान बनकर आएगा, आज का बेरोजगार युवा ...
# Row 74 | True: 0 | Pred: 0 | Text: ओए कानिये इतने जल्दी में ट्वीट क्यों कर देते हो...? भोसड़ीवा...
# Row 75 | True: 0 | Pred: 0 | Text: तू कहा अपना झोपड़ा मरवा रही है मादरचोद कूत्ती...
# Row 76 | True: 0 | Pred: 0 | Text: कमलनाथ सरकार ने साल 2018 में कलेक्टर पदनाम को बदलने के लिए प...
# Row 77 | True: 1 | Pred: 1 | Text: बीजेपी के खिलाफ लिखना (भौंकना) शुरू करो। कुछ दिन बाद वे आपसे...
# Row 78 | True: 0 | Pred: 0 | Text: भारत ने पिछले 24 घंटों में 65,081 रिकवरी (ठीक होने की दर) दर...
# Row 79 | True: 0 | Pred: 1 | Text: वो कुछ लोग जो मुल्ले है वो रिश्ते में तेरे बाप लगते है समझा ...
# Row 80 | True: 0 | Pred: 0 | Text: भेनचोद जहाँ दिखाया जा रहा वहां क्यों नहीं बोल रहा गांड फटती ...
# Row 81 | True: 0 | Pred: 1 | Text: मंदिर में पिटता कानून पुलिस वाले को केवल इसलिये पीटा गया क्य...
# Row 82 | True: 1 | Pred: 0 | Text: कुतिया की दुरसिस से हाथी नही मरते...
# Row 83 | True: 1 | Pred: 1 | Text: rt सारा खेल एकदम साफ़ है , gdp बस gravity की वजह से नीचे गिर...
# Row 84 | True: 1 | Pred: 1 | Text: 'मजहब नहीं सिखाता आपस में बैर रखना' ... यह लाइन सिर्फ हिंदुओ...
# Row 85 | True: 0 | Pred: 0 | Text: प्रशांत भूषण अवमानना मामले में सुप्रीम कोर्ट आज सुनाएगा फैसल...
# Row 86 | True: 1 | Pred: 1 | Text: तेरे जैसी हर रोज़ बीना वजह भोंकनेवाली कुतिया, कुत्ते की मौत ...
# Row 87 | True: 1 | Pred: 1 | Text: ये है बदलता हिन्दुस्तान.. जौनपुर की तस्वीर है ये...अब तो गां...
# Row 88 | True: 1 | Pred: 0 | Text: हमे अपना नारा लगवाने के लिए किसी को मारने की जरूरत नहीं ! बो...
# Row 89 | True: 0 | Pred: 0 | Text: नोवल कोरोनावायरस से संक्रमित 20,000 से अधिक रोगियों को मारने...
# Row 90 | True: 0 | Pred: 0 | Text: सुशांत सिंह राजपूत मामले में सीबीआई सच्चाई सामने लेकर आएगी: ...
# Row 91 | True: 0 | Pred: 0 | Text: सैफ अली खान एक सांस में तीन बार अलग अलग टोन में wow! wow! wo...
# Row 92 | True: 0 | Pred: 0 | Text: इसकी भेन को चोदू किसी को here maps की api यूज़ करते आता है क...
# Row 93 | True: 0 | Pred: 0 | Text: मजे की बात देखिए मौत सामने होते हुए भी भारतीय#सैनिक फौज की न...
# Row 94 | True: 1 | Pred: 0 | Text: भड़वा गिरी कर 2 करोड क्युं?? 20 करोड़ भी हो जाएंगे......
# Row 95 | True: 0 | Pred: 0 | Text: सुशांत केस में एक और ड्रग पेडलर गिरफ्तार sushantsinghrajputd...
# Row 96 | True: 0 | Pred: 0 | Text: अखबार की सुर्खी - कोर्ट की कसौटी पर खरा साबित हुआ pm केअर फण...
# Row 97 | True: 1 | Pred: 1 | Text: rt कंगना की जगह अगर सलमान भाई भाजपा में अा गए होते, तो भाजपा...
# Row 98 | True: 0 | Pred: 0 | Text: लो बे चमचो सबूत…..😉 कैसे बनी कैसे बनी……..! टमाटर बिना चटनी क...
# Row 99 | True: 0 | Pred: 0 | Text: मुंबई सबसे ज्यादा "टैक्स" भी दे और "जान" भी ? ताल ठोक के...
#
# SHAP results (head):
#    sentence_id     token  value_shap  \
# 0            0       देश    0.000629
# 1            0       में    0.000194
# 2            0  कोविड-19    0.001078
# 3            0        से   -0.000038
# 4            0  स्‍वस्‍थ   -0.024636
#
#                                             sentence  true_label  \
# 0  देश में कोविड-19 से स्‍वस्‍थ होने वालों की दर ...           0
# 1  देश में कोविड-19 से स्‍वस्‍थ होने वालों की दर ...           0
# 2  देश में कोविड-19 से स्‍वस्‍थ होने वालों की दर ...           0
# 3  देश में कोविड-19 से स्‍वस्‍थ होने वालों की दर ...           0
# 4  देश में कोविड-19 से स्‍वस्‍थ होने वालों की दर ...           0
#
#    predicted_label
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ✅ Saved SHAP token-level results to: ./indicbert_explainability/shap_results_100
# Row 0 | True: 0 | Pred: 0 | Text: देश में कोविड-19 से स्‍वस्‍थ होने वालों की दर बढ़कर 76.94 प्...
# Row 1 | True: 0 | Pred: 0 | Text: udan-4: ये हैं 78 नए रूट जहां हवाई सेवा को मिली मंजूरी, आपका...
# Row 2 | True: 0 | Pred: 0 | Text: और जिसका अर्थ समझ में आया, उसमे पता चला होगा की उनके पूर्वजो...
# Row 3 | True: 1 | Pred: 1 | Text: टीवी पर धार्मिक विवादों पर बहस दिखाने वाले पत्रकार जिम्मेवार...
# Row 4 | True: 1 | Pred: 1 | Text: aap to pura family ko le.dube bhaiya ji ....but koe nhi hm s...
# Row 5 | True: 1 | Pred: 1 | Text: कौन कह रहा है प्रदेश में भर्ती प्रकिया रुकी है?? हो तो रही ह...
# Row 6 | True: 1 | Pred: 1 | Text: ये तो साला नेता कम और छक्का ज्यादा लगता है!🤔😂 संजय_सिंह_गुंड...
# Row 7 | True: 0 | Pred: 0 | Text: amitshahhealthupdate: अमित शाह को एम्स से मिली छुट्टी, इलाज ...
# Row 8 | True: 1 | Pred: 1 | Text: गेंडा स्वामी कुत्ते की मौत मर गया साला ये घटना कब तक काल्पनि...
# Row 9 | True: 1 | Pred: 1 | Text: कांग्रेसी चमचे - राहुल गांधी हर मुद्दे पर मोदी जी से हार क्य...
# Row 10 | True: 1 | Pred: 1 | Text: अबे चरसी गांजाटी 'तेरी औकात नाही साले भडवे डूब मर काही जाके...
# Row 11 | True: 1 | Pred: 1 | Text: उद्धव ठाकरे शिवसेना को उसी ऊंचाई पर ले जाना चाहता हैं! जहाँ ...
# Row 12 | True: 0 | Pred: 0 | Text: स्वतंत्रता संग्राम की प्रथम महिला नायिका रानी लक्ष्मीबाई जी ...
# Row 13 | True: 1 | Pred: 1 | Text: rt प्राइवेट नौकरी करने वाले लड़के को अपने लिये लड़की ढूँढना ...
# Row 14 | True: 0 | Pred: 0 | Text: 74वें स्वतंत्रता दिवस के पावन अवसर पर... link...
# Row 15 | True: 1 | Pred: 1 | Text: link बुद्ध नगरी है.. इस वीडियो में देखें हर जगह बुद्ध ही बुद...
# Row 16 | True: 0 | Pred: 0 | Text: ने सोनिया गाँधी को फोन किया और बोला मैं काँग्रेस अध्यक्ष पद ...
# Row 17 | True: 0 | Pred: 0 | Text: फ्लिपकार्ट होलसेल ने किराना दुकानदारों को सेवाएं देना किया श...
# Row 18 | True: 1 | Pred: 0 | Text: tay ho gaya bhaiya ji ki kitne mai seat bechni hai congress ...
# Row 19 | True: 1 | Pred: 1 | Text: विजयमालिया ललितमोदी नीरवमोदी आसारामबापू बाबारामरहिम पर कोई ह...
# Row 20 | True: 0 | Pred: 0 | Text: आप एक साल तक बाहर नहीं जा सकते, ऐसे ही कुल 21 दिशा-निर्देश...
# Row 21 | True: 0 | Pred: 0 | Text: सेफ माने गए म्यूचुअल फंड भी दे रहे घाटा, आम निवेशक हो रहे नि...
# Row 22 | True: 1 | Pred: 1 | Text: इनके बापने कभी खेती नहीं कि होगी... सरकार तलवे भी चाटेगी इसक...
# Row 23 | True: 1 | Pred: 1 | Text: देखो ये कुतिया पुरी तरह से पगलागयी है यीससे बडा सबुत और क्या...
# Row 24 | True: 0 | Pred: 0 | Text: मुख्य आर्थिक सलाहकार ने कहा-देश में इस वर्ष अप्रैल से जून की...
# Row 25 | True: 1 | Pred: 0 | Text: संजय सिंह मादरचोद की औलाद है साला कुत्ता है...
# Row 26 | True: 1 | Pred: 1 | Text: ये भी हिन्दू रंडी है जो खुद उस कटवे से हमबिस्तरी को गयी है,व...
# Row 27 | True: 0 | Pred: 0 | Text: नहीं रहे भारत के पूर्व राष्ट्रपति प्रणब मुखर्जी pranabmukher...
# Row 28 | True: 1 | Pred: 1 | Text: आतंकवादी हमले के आरोपी साध्वी प्रज्ञा_ठाकुर का संसद पहुंचना ...
# Row 29 | True: 0 | Pred: 0 | Text: नीतीश कुमार ने जेडीयू के वर्चुअल सम्मेलन में सुशांत सिंह राज...
# Row 30 | True: 1 | Pred: 1 | Text: ला़कडाउन की वजह से शादीशुदा महिलाओं की नौकरानी जैसी हैसियत ह...
# Row 31 | True: 1 | Pred: 0 | Text: ये क्या है ,आप लोग क्या कर रहे है ,*bjp विधायक अनिल* *उपाध्य...
# Row 32 | True: 0 | Pred: 0 | Text: जिहाद, आतंकवाद, पत्थरबाज, भारत विरोधी नारे, पाकिस्तान समर्थक...
# Row 33 | True: 1 | Pred: 0 | Text: दिल्ली में दो समुदायों को कौन लड़ाना चाहता है? dangal पूरा क...
# Row 34 | True: 0 | Pred: 0 | Text: आज 30 jun 19 ko मैंने एक ‘योगा एंड हीलिंग सेंटर’ का शुभारम्भ...
# Row 35 | True: 1 | Pred: 1 | Text: बेशर्मी तो तुम दिखाते हो हरामखोर,डरा हुआ मुसलमान ही सौ साल प...
# Row 36 | True: 0 | Pred: 0 | Text: अबे कमिने राज्यसभा में इस तरह के कार्य को गुंडागर्दी कहते है...
# Row 37 | True: 0 | Pred: 0 | Text: sureshraina के ट्वीट के बाद पंजाब पुलिस का बड़ा फैसला link...
# Row 38 | True: 1 | Pred: 1 | Text: माननीय सांसद ने "जय हिन्द" और "जय भीम" भी कहा था, लेकिन आपको...
# Row 39 | True: 1 | Pred: 1 | Text: भारत में मुस्लिमों द्वारा सोशल डिस्टेंसिंग को फॉलो नहीं किया...
# Row 40 | True: 1 | Pred: 0 | Text: प्रधानमंत्री आवास योजना के तहत 30 लाख से अधिक आवास निर्मित उ...
# Row 41 | True: 1 | Pred: 1 | Text: rt अपनी औकात में रहो पाकिस्तान जितनी तुम्हारे यहाँ सरकारी कम...
# Row 42 | True: 1 | Pred: 1 | Text: ट्रम्प हमारे लोकतंत्र के लिए खतरा हैं! इसके अलावा, अगर मेरा ...
# Row 43 | True: 0 | Pred: 0 | Text: उत्तराखंड की जनता इस बार आम आदमी पार्टी के साथ मिलकर अपने अध...
# Row 44 | True: 1 | Pred: 1 | Text: इतना गुंडा गर्दी करने के बाद ठाकरे कहता है 🤔 हमारी खामोशी को...
# Row 45 | True: 1 | Pred: 0 | Text: दिल्ली में आयुष्मान भारत योजना को रोक कर मुख्यमंत्री केजरीवा...
# Row 46 | True: 0 | Pred: 0 | Text: समाजवादी की पहचान ही संघर्ष है जय समाजवाद...
# Row 47 | True: 1 | Pred: 1 | Text: rt केजरीवाल की आंखे 🙄 भर आईं और बोले मेरे से ज्यादा गाली खान...
# Row 48 | True: 0 | Pred: 0 | Text: पालतू जानवरों जैसे बिल्लियों या कुत्तों द्वारा covid19 इंसान...
# Row 49 | True: 1 | Pred: 1 | Text: जब तक गोरखपुर में बीजेपी का शासन है तब तक गोरखपुर का कुछ नही...
# Row 50 | True: 1 | Pred: 1 | Text: आज सरकार कश्मीर समस्या पर तो बहस करना चाहती है,लेकिन evm समस...
# Row 51 | True: 1 | Pred: 1 | Text: देख लो हिन्दुस्ता के लोगो आज तिरंगा जला रहे है साले कल लोगो ...
# Row 52 | True: 1 | Pred: 1 | Text: हिंदुस्तान के अंदर हिंदुओं का ही धर्मपरिवर्तन हिंदू बेटियों ...
# Row 53 | True: 1 | Pred: 1 | Text: अभिनेत्री जायरा ने "इस्लाम में अभिनय हराम" बता फिल्में छोड़ी...
# Row 54 | True: 1 | Pred: 1 | Text: यह हरामि दिल्ली मुसलमान को तालिबानी कह रही है इसको सही जवाब ...
# Row 55 | True: 0 | Pred: 0 | Text: biharelection: बिहार चुनाव के लिए rjd का हेडक्वार्टर बना rim...
# Row 56 | True: 1 | Pred: 1 | Text: हिंदुओं की समस्या का मूल कारन हिन्दुओं का चुप रहना है, उसको ...
# Row 57 | True: 0 | Pred: 0 | Text: कंगना को अगर मुख्यमंत्री को 'तू' बोलने पर y+ सुरक्षा दी जाती...
# Row 58 | True: 1 | Pred: 1 | Text: आर्मी में चमचा गिरी की परंपरा को इसने शुरू किया है । सत्ता क...
# Row 59 | True: 0 | Pred: 0 | Text: राष्टीय अध्यक्ष जी निवेदन है सपा पार्टी में हर समाज के लोगों...
# Row 60 | True: 0 | Pred: 0 | Text: उत्तराखंड के इस जिले में बढ़ता जा रहा कोरोना संक्रमण, पुलिस ...
# Row 61 | True: 0 | Pred: 0 | Text: साला समझ मे नही आता🙄 मुहल्ले के बच्चों को नॉटी कैसे,बोलू संज...
# Row 62 | True: 0 | Pred: 1 | Text: झारखंड के मुस्लिम चोर की बीबी को सरकारी नौकरी और 5 लाख रुपये...
# Row 63 | True: 1 | Pred: 0 | Text: और ये काम कौन करेगा? आप लोग रिपोर्टिंग तो करते नहीं राजनीति ...
# Row 64 | True: 0 | Pred: 0 | Text: अमेरिकी शोधकर्ताओं का दावा: बिल्लियों को दी जाने वाली एंटीवा...
# Row 65 | True: 0 | Pred: 0 | Text: संसद लोकतंत्र का मंदिर ही क्यों ? चर्च, गुरुद्वारा या मस्जिद...
# Row 66 | True: 1 | Pred: 1 | Text: मोदी जी ने इतना पुख़्ता काम कर दिया है कि अगली बार जो भी सत्...
# Row 67 | True: 0 | Pred: 0 | Text: ब्रिटेन के प्रधानमंत्री बोरिस जॉनसन ने यूरोपीय संघ को व्यापा...
# Row 68 | True: 0 | Pred: 0 | Text: मेहबूबा शर्म कर रंडी हरे रंग वाली छिनाल कोई कुछ भी...
# Row 69 | True: 0 | Pred: 0 | Text: सदर पर हमला, मलखान में भर्ती अल्लाह पाक जल्द सिफा अताह फ़रमा...
# Row 70 | True: 0 | Pred: 0 | Text: कन्हैया_कुमार के खिलाफ कोई भी देश द्रोह का सबूत नहीं होने के...
# Row 71 | True: 1 | Pred: 1 | Text: चुप mc कहीं का, अनपढ़, गंवार कमीना, हरामखोर।...
# Row 72 | True: 0 | Pred: 0 | Text: गांड पे लात मार के नीकाल फेंको बाप बेचे को पार्टी से बहार...
# Row 73 | True: 1 | Pred: 1 | Text: rt तुम रोक ना पाओगे वह तूफान बनकर आएगा, आज का बेरोजगार युवा ...
# Row 74 | True: 0 | Pred: 0 | Text: ओए कानिये इतने जल्दी में ट्वीट क्यों कर देते हो...? भोसड़ीवा...
# Row 75 | True: 0 | Pred: 0 | Text: तू कहा अपना झोपड़ा मरवा रही है मादरचोद कूत्ती...
# Row 76 | True: 0 | Pred: 0 | Text: कमलनाथ सरकार ने साल 2018 में कलेक्टर पदनाम को बदलने के लिए प...
# Row 77 | True: 1 | Pred: 1 | Text: बीजेपी के खिलाफ लिखना (भौंकना) शुरू करो। कुछ दिन बाद वे आपसे...
# Row 78 | True: 0 | Pred: 0 | Text: भारत ने पिछले 24 घंटों में 65,081 रिकवरी (ठीक होने की दर) दर...
# Row 79 | True: 0 | Pred: 1 | Text: वो कुछ लोग जो मुल्ले है वो रिश्ते में तेरे बाप लगते है समझा ...
# Row 80 | True: 0 | Pred: 0 | Text: भेनचोद जहाँ दिखाया जा रहा वहां क्यों नहीं बोल रहा गांड फटती ...
# Row 81 | True: 0 | Pred: 1 | Text: मंदिर में पिटता कानून पुलिस वाले को केवल इसलिये पीटा गया क्य...
# Row 82 | True: 1 | Pred: 0 | Text: कुतिया की दुरसिस से हाथी नही मरते...
# Row 83 | True: 1 | Pred: 1 | Text: rt सारा खेल एकदम साफ़ है , gdp बस gravity की वजह से नीचे गिर...
# Row 84 | True: 1 | Pred: 1 | Text: 'मजहब नहीं सिखाता आपस में बैर रखना' ... यह लाइन सिर्फ हिंदुओ...
# Row 85 | True: 0 | Pred: 0 | Text: प्रशांत भूषण अवमानना मामले में सुप्रीम कोर्ट आज सुनाएगा फैसल...
# Row 86 | True: 1 | Pred: 1 | Text: तेरे जैसी हर रोज़ बीना वजह भोंकनेवाली कुतिया, कुत्ते की मौत ...
# Row 87 | True: 1 | Pred: 1 | Text: ये है बदलता हिन्दुस्तान.. जौनपुर की तस्वीर है ये...अब तो गां...
# Row 88 | True: 1 | Pred: 0 | Text: हमे अपना नारा लगवाने के लिए किसी को मारने की जरूरत नहीं ! बो...
# Row 89 | True: 0 | Pred: 0 | Text: नोवल कोरोनावायरस से संक्रमित 20,000 से अधिक रोगियों को मारने...
# Row 90 | True: 0 | Pred: 0 | Text: सुशांत सिंह राजपूत मामले में सीबीआई सच्चाई सामने लेकर आएगी: ...
# Row 91 | True: 0 | Pred: 0 | Text: सैफ अली खान एक सांस में तीन बार अलग अलग टोन में wow! wow! wo...
# Row 92 | True: 0 | Pred: 0 | Text: इसकी भेन को चोदू किसी को here maps की api यूज़ करते आता है क...
# Row 93 | True: 0 | Pred: 0 | Text: मजे की बात देखिए मौत सामने होते हुए भी भारतीय#सैनिक फौज की न...
# Row 94 | True: 1 | Pred: 0 | Text: भड़वा गिरी कर 2 करोड क्युं?? 20 करोड़ भी हो जाएंगे......
# Row 95 | True: 0 | Pred: 0 | Text: सुशांत केस में एक और ड्रग पेडलर गिरफ्तार sushantsinghrajputd...
# Row 96 | True: 0 | Pred: 0 | Text: अखबार की सुर्खी - कोर्ट की कसौटी पर खरा साबित हुआ pm केअर फण...
# Row 97 | True: 1 | Pred: 1 | Text: rt कंगना की जगह अगर सलमान भाई भाजपा में अा गए होते, तो भाजपा...
# Row 98 | True: 0 | Pred: 0 | Text: लो बे चमचो सबूत…..😉 कैसे बनी कैसे बनी……..! टमाटर बिना चटनी क...
# Row 99 | True: 0 | Pred: 0 | Text: मुंबई सबसे ज्यादा "टैक्स" भी दे और "जान" भी ? ताल ठोक के...
# ✅ Saved LIME results to: ./indicbert_explainability/lime_results_100
#    sentence_id     token  value_lime  \
# 0            0       देश    0.020816
# 1            0       में    0.024638
# 2            0  कोविड-19   -0.045759
# 3            0        से   -0.016443
# 4            0  स्‍वस्‍थ   -0.051264
#
#                                             sentence  true_label  \
# 0  देश में कोविड-19 से स्‍वस्‍थ होने वालों की दर ...           0
# 1  देश में कोविड-19 से स्‍वस्‍थ होने वालों की दर ...           0
# 2  देश में कोविड-19 से स्‍वस्‍थ होने वालों की दर ...           0
# 3  देश में कोविड-19 से स्‍वस्‍थ होने वालों की दर ...           0
# 4  देश में कोविड-19 से स्‍वस्‍थ होने वालों की दर ...           0
#
#    predicted_label
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# SHAP shape: (2181, 6)
# LIME shape: (2181, 6)
#
# Merged shape: (2527, 7)
# Similarity rows: 100
#
# Confidence distribution:
# confidence_level
# Low       50
# Medium    15
# High      35
# Name: count, dtype: int64
#
# Average agreement metrics:
#   Cosine similarity:   0.095
#   Pearson correlation: 0.074
#   JS divergence:       0.153
#
# ✅ Saved similarity + confidence to: ./indicbert_explainability/explainability_results_100
